# %% [markdown]
# # Design an ERD
# ![books_ERD.png](attachment:a50473be-b10d-4069-9958-f7f1e4eb030b.png)

# %%
from sqlalchemy.engine import create_engine
import pymysql
pymysql.install_as_MySQLdb()
from urllib.parse import quote_plus
import pandas as pd

# %%
# Create the sqlalchemy engine and connection
username = "root"
password = "root" 
db_name = "books"
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"
engine = create_engine(connection)
conn = engine.connect()

# %%
# Loading data files
users = pd.read_csv('data/users.csv')
books = pd.read_csv('data/books.csv')
favorites = pd.read_csv('data/favorites.csv')
authors = pd.read_csv('data/authors.csv')

# %%
# Describe table 'users'
q = ''' DESCRIBE users;'''

describe_users = pd.read_sql(q, conn)
describe_users
# Out:
#         Field         Type Null  Key Default Extra
# 0          id          int   NO  PRI    None
# 1  first name  varchar(45)  YES         None
# 2   last name  varchar(45)  YES         None
# 3       email  varchar(45)  YES         None

# %%
# Checking describe's field names
describe_users['Field'].values
# Out:
# array(['id', 'first name', 'last name', 'email'], dtype=object)

# %%
# Checking dataframe's columns
users.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email'], dtype='object')

# %%
# Reviewing SQL table's data typpes 
describe_users[['Field', 'Type']]
# Out:
#         Field         Type
# 0          id          int
# 1  first name  varchar(45)
# 2   last name  varchar(45)
# 3       email  varchar(45)

# %%
# Reviewing dataframe's data types
users.dtypes
# Out:
# id             int64
# first_name    object
# last_name     object
# email         object
# dtype: object

# %%
# Describe table 'books'
q = ''' DESCRIBE books;'''

describe_books = pd.read_sql(q, conn)
describe_books
# Out:
#          Field         Type Null  Key Default Extra
# 0           id          int   NO  PRI    None
# 1        title  varchar(45)  YES         None
# 2  authors_ id          int   NO  PRI    None

# %%
# Checking describe's field names
describe_books['Field'].values
# Out:
# array(['id', 'title', 'authors_ id'], dtype=object)

# %%
# Checking dataframe's columns
books.columns
# Out:
# Index(['id', 'title', 'author_id'], dtype='object')

# %%
# Reviewing SQL table's data typpes 
describe_books[['Field', 'Type']]
# Out:
#          Field         Type
# 0           id          int
# 1        title  varchar(45)
# 2  authors_ id          int

# %%
# Reviewing dataframe's data types
books.dtypes
# Out:
# id            int64
# title        object
# author_id     int64
# dtype: object

# %%
# Describe table 'books'
q = ''' DESCRIBE favorites;'''

describe_favorites = pd.read_sql(q, conn)
describe_favorites
# Out:
#                Field Type Null  Key Default Extra
# 0           books_id  int   NO  MUL    None
# 1  books_authors_ id  int   NO         None
# 2           users_id  int   NO  MUL    None

# %%
# Checking describe's field names
describe_favorites['Field'].values
# Out:
# array(['books_id', 'books_authors_ id', 'users_id'], dtype=object)

# %%
# Checking dataframe's columns
favorites.columns
# Out:
# Index(['user_id', 'book_id'], dtype='object')

# %%
# Describe table 'authors'
q = ''' DESCRIBE authors;'''

describe_authors = pd.read_sql(q, conn)
describe_authors
# Out:
#          Field         Type Null  Key Default Extra
# 0           id          int   NO  PRI    None
# 1  author_name  varchar(45)  YES         None
